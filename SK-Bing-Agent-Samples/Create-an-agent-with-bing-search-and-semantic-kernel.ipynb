# %% [markdown]
# # Use an existing Bing Agent with Semantic Kernel
# This notebook demonstrates how to create a Bing Agent using Semantic Kernel. It includes a custom monkey-patch for citation URL extraction and shows how to simulate a conversation with an existing Azure AI Agent.

# %% [markdown]
# ## Prerequisties
#
# #### Complete the agent setup and create a project connection to a Bing  resource
#
# 1. Create an agent project by deploying a template in the [quickstart](https://learn.microsoft.com/azure/ai-services/agents/quickstart?pivots=programming-language-python-azure).
#
# 2. Create a Grounding with Bing Search resource and create a project connection to this resource. [Learn more](https://learn.microsoft.com/en-us/azure/ai-services/agents/how-to/tools/bing-grounding?tabs=python&pivots=overview)
#     1. You need to have `Owner` or `Contributor` role in your subscription or resource group to create it.

# %% [markdown]
# #### Install the required libraries
# In this section, we import all the libraries we need. The code imports asynchronous Azure Identity for authentication and the necessary Semantic Kernel modules to work with Azure AI Agents.

# %%
# %pip install azure-ai-projects
# %pip install azure-identity
# %pip install semantic-kernel[azure]
# Out:
# Requirement already satisfied: azure-ai-projects in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (1.0.0b6)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-projects) (1.32.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-projects) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-projects) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-projects) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (1.20.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (308)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: semantic-kernel[azure] in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (1.23.0)
# Requirement already satisfied: aiohttp~=3.8 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (3.11.13)
# Requirement already satisfied: cloudevents~=1.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.11.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (2.10.6)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (2.8.1)
# Requirement already satisfied: defusedxml~=0.7 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (0.7.1)
# Requirement already satisfied: azure-identity~=1.13 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.20.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (2.2.3)
# Requirement already satisfied: openai~=1.61 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.65.4)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (0.19.4)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.30.0)
# Requirement already satisfied: prance~=23.6.21.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.15.2)
# Requirement already satisfied: azure-ai-inference>=1.0.0b6 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects>=1.0.0b5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.0.0b6)
# Requirement already satisfied: azure-core-tracing-opentelemetry>=1.0.0b11 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (1.0.0b11)
# Requirement already satisfied: azure-search-documents>=11.6.0b4 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (11.6.0b9)
# Requirement already satisfied: azure-cosmos~=4.7 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from semantic-kernel[azure]) (4.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (1.18.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-inference>=1.0.0b6->semantic-kernel[azure]) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-inference>=1.0.0b6->semantic-kernel[azure]) (1.32.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-ai-inference>=1.0.0b6->semantic-kernel[azure]) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity~=1.13->semantic-kernel[azure]) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity~=1.13->semantic-kernel[azure]) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-identity~=1.13->semantic-kernel[azure]) (1.2.0)
# Requirement already satisfied: azure-common>=1.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from azure-search-documents>=11.6.0b4->semantic-kernel[azure]) (1.1.28)
# Requirement already satisfied: deprecation<3.0,>=2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from cloudevents~=1.0->semantic-kernel[azure]) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jinja2~=3.1->semantic-kernel[azure]) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openai~=1.61->semantic-kernel[azure]) (4.67.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.3.4)
# Requirement already satisfied: more-itertools in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (10.6.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.7.1)
# Requirement already satisfied: parse in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (3.1.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel[azure]) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel[azure]) (8.5.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel[azure]) (0.51b0)
# Requirement already satisfied: chardet>=3.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel[azure]) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel[azure]) (0.18.10)
# Requirement already satisfied: requests>=2.25 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel[azure]) (2.32.3)
# Requirement already satisfied: six~=1.15 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel[azure]) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel[azure]) (24.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from pybars4~=0.9->semantic-kernel[azure]) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel[azure]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel[azure]) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from pydantic-settings~=2.0->semantic-kernel[azure]) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from anyio<5,>=3.5.0->openai~=1.61->semantic-kernel[azure]) (3.10)
# Requirement already satisfied: cffi>=1.12 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from cryptography>=2.5->azure-identity~=1.13->semantic-kernel[azure]) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel[azure]) (1.17.2)
# Requirement already satisfied: certifi in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel[azure]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel[azure]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai~=1.61->semantic-kernel[azure]) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel[azure]) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.23.1)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity~=1.13->semantic-kernel[azure]) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from msal-extensions>=1.2.0->azure-identity~=1.13->semantic-kernel[azure]) (2.10.1)
# Requirement already satisfied: rfc3339-validator in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel[azure]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel[azure]) (2.3.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from ruamel.yaml>=0.17.10->prance~=23.6.21.0->semantic-kernel[azure]) (0.2.12)
# Requirement already satisfied: colorama in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from tqdm>4->openai~=1.61->semantic-kernel[azure]) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity~=1.13->semantic-kernel[azure]) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\fosteramanda\documents\agents + sk\semantic-kernel\python\samples\getting_started_with_agents\azure_ai_agent\venv\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity~=1.13->semantic-kernel[azure]) (308)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 1: Import required libraries

# %%
import asyncio

from azure.identity.aio import DefaultAzureCredential
from azure.ai.projects.models import BingGroundingTool


from semantic_kernel.agents.azure_ai import AzureAIAgent, AzureAIAgentSettings, agent_content_generation
from semantic_kernel.contents import AuthorRole

# %% [markdown]
# ## Step 2: Annotation path for Bing urls
# Here, we override the default annotation processing function to capture citation URLs when they're returned by the agent. The new function checks if the annotation has the required attributes (start_index and end_index) and, if it’s a URL citation, extracts and prints the Bing Search URL. The semantic kernel Agent SDK only supports file search annotations currently.

# %%
# Global variable to store citation URLs
citation_url = "No citations available"

# Save the original function
original_generate_annotation_content = agent_content_generation.generate_annotation_content
def patched_generate_annotation_content(annotation):
    global citation_url
    print("Patched function called")  # Debug print
    
    # Ensure that the annotation has both 'start_index' and 'end_index' attributes.
    # print(f"# Annotation before: '{annotation}'")
    if not hasattr(annotation, "start_index"):
        setattr(annotation, "start_index", None)
        # print(f"# Annotation set start_index: '{annotation}'")
    if not hasattr(annotation, "end_index"):
        setattr(annotation, "end_index", None)
        # print(f"# Annotation set end_index: '{annotation}'")

    # print(f"# Annotation after: '{annotation}'")
    # Check if this is a URL citation annotation and expose the URL
    if hasattr(annotation, 'type') and annotation.type == 'url_citation':
        try:
            citation_url = annotation['url_citation']['url']
            # print(f"# Citation url: '{citation_url}'")
            return annotation
        except Exception as e:
            print(f"Error processing citation: {e}")
    # Return the annotation as is for other annotation types
    return annotation

# Apply the monkey-patch
agent_content_generation.generate_annotation_content = patched_generate_annotation_content

print("Bing citation patch function run")  # Debug print
# Out:
# Bing citation patch function run

# %% [markdown]
# ## Step 3: Conversation Setup
#
# 1. **Retrieve Bing Connection and Initialize Tool:**
#
#     First, the program retrieves your project's Bing connection and initializes the Grounding with Bing Search tool.
#
# 1. **Define an Agent with the Bing Tool Enabled**
#
#     Next, an agent definition is created using Azure AI Agent Service, and the Bing Search tool is attached.
#
# 1. **Initialize Semantic Kernel Agent:**
#
#     Then, the semantic kernel agent is initialized using the defintion.
#
# 1.  **Stimulate a Conversation:**
#
#     Finally, a conversation thread is created. A user message is sent to the agent, which generates a response. The agent's reply is displayed along with any citation URLs captured by the patched annotation function.

# %%
# Simulate a conversation with the agent
USER_INPUTS = [
    "What is the weather in seattle?",
]

# %%
ai_agent_settings = AzureAIAgentSettings.create()
async def main() -> None:
    async with (
        DefaultAzureCredential() as creds,
        AzureAIAgent.create_client(credential=creds) as client,
    ):
        
         # Get your Bing connection        
        bing_connection = await client.connections.get(
                connection_name="decdemobing", include_credentials=True  # Optional. Defaults to "False"
        )
        conn_id = bing_connection.id
        print(conn_id)

        # Initialize the Bing Search tool
        bing = BingGroundingTool(connection_id=conn_id)
        
        # 1. Create an agent using Azure AI agent service
        agent_definition = await client.agents.create_agent(
            model=ai_agent_settings.model_deployment_name,
            name="Bing Agent",
            instructions="Answer the user's questions.",
            tools=bing.definitions,
            headers={"x-ms-enable-preview": "true"},
        )
        print("Created agent definition")
        
        agent_definition = await client.agents.get_agent(
            assistant_id="asst_dD17QuoyrPo14guVyzKAJkX2",
        )

        # 2. Create a Semantic Kernel agent for the Azure AI agent
        agent = AzureAIAgent(
            client=client,
            definition=agent_definition,
        )

        # 3. Create a new thread on the Azure AI agent service
        thread = await client.agents.create_thread()
        try:
            for user_input in USER_INPUTS:
                
                # 4. Add the user input as a chat message
                await agent.add_chat_message(thread_id=thread.id, message=user_input)
                print(f"# User: '{user_input}'")


                # 5. Invoke the agent for the specified thread for response
                response = await agent.get_response(thread_id=thread.id)
                print(f"# {response.name}: {response}")

                 # Retrieve run step details to get Bing Search query link
                 # This code is not working so it is commented out
                # runs = await client.agents.list_runs(thread_id=thread.id)
                # print(f"# The most recent run: '{runs}'")

                # run_id = runs['last_id']
                # print(f"# The most recent run_id: '{run_id}'")


                # run_steps = await client.agents.list_run_steps(run_id = run_id, thread_id=thread.id)
                # for run_step in run_steps['data']:
                #     if 'bing_search_query' in run_step:
                #         search_query = run_step['bing_search_query']
                #         bing_search_url = f"https://www.bing.com/search?q={search_query.replace(' ', '+')}"
                #         print(f"Bing Search URL: {bing_search_url}")
                # Print the captured citation URL
                print(f"Citation URL: {citation_url}")


        finally:
            # 6. Cleanup: Delete the thread and agent
            await client.agents.delete_thread(thread.id)
            # Do not clean up the assistant so it can be used again

# %%
await main()
# Out:
# /subscriptions/921496dc-987f-410f-bd57-426eb2611356/resourceGroups/rg-amanda-standard/providers/Microsoft.MachineLearningServices/workspaces/project-demo-dyl6/connections/decdemobing
# Created agent definition
# # User: 'What is the weather in seattle?'
# Patched function called
# # BingAgent: The weather in Seattle today, March 10, 2025, is cloudy with a high temperature around 50°F and a low around 40°F. Winds are expected to be from the south at 5 to 10 mph【3†source】.
# Citation URL: https://world-weather.info/forecast/usa/seattle/march-2025/
